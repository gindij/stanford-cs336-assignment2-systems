# %%
# !rm -rf stanford-cs336-assignment2-systems && git clone https://github.com/gindij/stanford-cs336-assignment2-systems.git
# Out:
# Cloning into 'stanford-cs336-assignment2-systems'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 139 (delta 2), reused 10 (delta 2), pack-reused 128 (from 2)
# Receiving objects: 100% (139/139), 957.60 KiB | 7.72 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("stanford-cs336-assignment2-systems")
# Out:
# Mounted at /content/drive

# %%
# !uv sync && source .venv/bin/activate
# Out:
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 78 packages in 10ms
# Prepared 75 packages in 1m 19s
# Installed 75 packages in 853ms
#  + annotated-types==0.7.0
#  + certifi==2025.1.31
#  + charset-normalizer==3.4.1
#  + click==8.1.8
#  + cloudpickle==3.1.1
#  + contourpy==1.3.2
#  + cs336-basics==1.0.3 (from file:///content/stanford-cs336-assignment2-systems/cs336-basics)
#  + cs336-systems==1.0.4 (from file:///content/stanford-cs336-assignment2-systems)
#  + cycler==0.12.1
#  + docker-pycreds==0.4.0
#  + einops==0.8.1
#  + einx==0.3.0
#  + filelock==3.18.0
#  + fonttools==4.57.0
#  + frozendict==2.4.6
#  + fsspec==2025.3.2
#  + gitdb==4.0.12
#  + gitpython==3.1.44
#  + humanfriendly==10.0
#  + idna==3.10
#  + iniconfig==2.1.0
#  + jaxtyping==0.3.1
#  + jinja2==3.1.6
#  + kiwisolver==1.4.8
#  + markupsafe==3.0.2
#  + matplotlib==3.10.1
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.5
# ...

# %%
# !pip install -e cs336-basics
# Out:
# Obtaining file:///content/stanford-cs336-assignment2-systems/cs336-basics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for cs336_basics (pyproject.toml) ... done
#   Created wheel for cs336_basics: filename=cs336_basics-1.0.3-0.editable-py3-none-any.whl size=3180 sha256=2ac0b9f32685de03a6583f03a95179488da51823a8a89fd8e57f5e4d1435f262
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7c9c2w37/wheels/f0/85/3d/48bb85dd18278f39a88c8b6885e20b2567554cb8d19652ff97
# Successfully built cs336_basics
# ...
#   Attempting uninstall: cs336_basics
#     Found existing installation: cs336_basics 1.0.3
#     Uninstalling cs336_basics-1.0.3:
#       Successfully uninstalled cs336_basics-1.0.3
# ...

# %%
# !python -m cs336_systems.basic --profile-forward --profile-backward --warmup-steps 5 --profiling-steps 10 --batch-size 16 --context-length 128 --output-file output.csv

# %%
# !python -m cs336_systems.basic --profile-forward --profile-backward --warmup-steps 0 --profiling-steps 10 --batch-size 16 --context-length 128 --output-file output_no_warmup.csv

# %%
# !cat output_no_warmup.csv

# %%
# !cat output.csv

# %% [markdown]
# ### Using nsys

# %%
# !apt-get install -y "nsight-systems-2025.5.2"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxkbcommon-x11-0 libxtst6
# The following NEW packages will be installed:
#   libxcb-cursor0 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxkbcommon-x11-0 libxtst6 nsight-systems-2025.5.2
# 0 upgraded, 13 newly installed, 0 to remove and 37 not upgraded.
# Need to get 411 MB of archives.
# After this operation, 784 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# ...

# %%
# !uv run nsys profile --pytorch=autograd-nvtx -o result python -m cs336_systems.basic --profile-forward --profile-backward --profile-optimizer --context-length 128 --output-file output_nsys.csv
# Out:
# ...
# profiling small
# ...
# Profiling: 100%|██████████| 10/10 [00:01<00:00,  6.37it/s]
# profiling medium
# ...
# Profiling: 100%|██████████| 10/10 [00:03<00:00,  3.04it/s]
# profiling large
# ...
# Profiling: 100%|██████████| 10/10 [00:05<00:00,  1.96it/s]
# profiling xl
# Warm-up:   0%|          | 0/5 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/stanford-cs336-assignment2-systems/stanford-cs336-assignment2-systems/cs336_systems/basic.py", line 121, in <module>
#     main(args)
#   File "/content/stanford-cs336-assignment2-systems/stanford-cs336-assignment2-systems/cs336_systems/basic.py", line 59, in main
#     optimizer.step()
#   File "/content/stanford-cs336-assignment2-systems/stanford-cs336-assignment2-systems/.venv/lib/python3.12/site-packages/torch/optim/optimizer.py", line 493, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !cp /tmp/nsys-report-38e8.nsys-rep /content/drive/MyDrive/stanford-cs336-assignment2-systems/annot-report-opt.nsys-rep

# %% [markdown]
# ### Mixed precision

# %%
# !python -m cs336_systems.benchmarking --profile-forward --profile-backward --warmup-steps 5 --profiling-steps 10 --batch-size 16 --context-length 128 --output-file output_mp.csv --use-mixed-precision
# Out:
# profiling small
# Warm-up:  40% 2/5 [37:57<57:04, 1141.61s/it]
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-3ie4w6m78hd0i-c.us-west1-0.prod.colab.dev/'. Verify the server is running and reachable.

# %%
# !python -m cs336_systems.benchmarking --profile-forward --profile-backward --warmup-steps 5 --profiling-steps 10 --batch-size 16 --context-length 128 --output-file output_no_mp.csv
